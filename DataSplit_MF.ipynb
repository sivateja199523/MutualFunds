# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mutual_funds=pd.read_csv('Mutual Funds.csv')
# Out:
# /Users/sivateja/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (20,22,23,119,121,123) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
mutual_funds.head()
# Out:
#   fund_name                                 fund_extended_name  \
# 0     AAAAX               DWS RREEF Real Assets Fund - Class A
# 1     AAADX               Aberdeen Income Builder Fund Class A
# 2     AAAGX             Thrivent Large Cap Growth Fund Class A
# 3     AAAIX  American Century Strategic Allocation: Aggress...
# 4     AAANX  Horizon Active Asset Allocation Fund Investor ...
#
#                          category                   fund_family    net_assets  \
# 0                World Allocation                           DWS  5.302800e+08
# 1                     Large Blend                      Aberdeen  8.884000e+07
# 2                    Large Growth                Thrivent Funds  1.080000e+09
# 3  Allocation - 70% to 85% Equity  American Century Investments  7.852700e+08
# 4             Tactical Allocation           Horizon Investments  5.271300e+08
#
#    ytd_return  fund_yield  morningstar_rating inception_date investment  \
# ...

# %%
mutual_funds.shape
# Out:
# (25308, 125)

# %%
Columns_to_keep=["fund_name","investment","size","ytd_return" ,"fund_yield","net_annual_expense_ratio_fund"  
 , "portfolio_stocks" ,                   "portfolio_bonds"                    
, "price_earnings"  ,                    "price_book"                         
,"price_sales"   ,                      "price_cashflow"                     
,"fund_return_ytd"                                   
,            "fund_return_1year"                  
,            "fund_return_3years"                 
,         "fund_return_5years"                 
,           "fund_return_10years"                
,           "fund_return_2018"                   
, "fund_return_2017"       ,             "fund_return_2016"                   
, "fund_return_2015"       ,             "fund_return_2014"                   
, "fund_return_2013"       ,             "fund_return_2012"                   
, "fund_return_2011"       ,             "fund_return_2010"                   
, "fund_alpha_3years"                   
, "fund_alpha_5years"                
, "fund_alpha_10years"                
, "fund_beta_3years"                      
, "fund_beta_5years"                       
, "fund_beta_10years"                     
, "fund_mean_annual_return_3years"
, "fund_mean_annual_return_5years"
, "fund_mean_annual_return_10years" 
, "fund_r_squared_3years"               
, "fund_r_squared_5years"                 
, "fund_r_squared_10years"               
, "fund_standard_deviation_3years" 
, "fund_standard_deviation_5years"  
, "fund_standard_deviation_10years" 
, "fund_sharpe_ratio_3years"          
, "fund_sharpe_ratio_5years"             
, "fund_sharpe_ratio_10years"            
, "fund_treynor_ratio_3years"            
, "fund_treynor_ratio_5years"        
, "fund_treynor_ratio_10years"   ]

# %%
mutual_funds_1=mutual_funds[Columns_to_keep]

# %%
mutual_funds_1.shape
# Out:
# (25308, 47)

# %%
mutual_funds_countnull = mutual_funds_1.isna().mean().round(4) * 100

# %%
export_csv=mutual_funds_countnull.to_csv(r'Mutual funds missing value percentage.csv')

# %%
export_csv_1=mutual_funds_1.to_csv(r'Mutual_funds_1.csv')

# %%
corr=mutual_funds_1.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
relavent_features=corr[corr>0.8]

# %%
relavent_features
# Out:
#                                  ytd_return  fund_yield  \
# ytd_return                         1.000000         NaN
# fund_yield                              NaN         1.0
# net_annual_expense_ratio_fund           NaN         NaN
# portfolio_stocks                        NaN         NaN
# portfolio_bonds                         NaN         NaN
# price_book                              NaN         NaN
# fund_return_ytd                    0.999502         NaN
# fund_return_1year                       NaN         NaN
# fund_return_3years                      NaN         NaN
# fund_return_5years                      NaN         NaN
# fund_return_10years                     NaN         NaN
# fund_return_2018                        NaN         NaN
# fund_return_2017                        NaN         NaN
# fund_return_2016                        NaN         NaN
# fund_return_2015                        NaN         NaN
# fund_return_2014                        NaN         NaN
# ...

# %%
highestcorr=["fund_return_ytd","fund_mean_annual_return_3years","fund_mean_annual_return_5years","fund_standard_deviation_5years","fund_mean_annual_return_10years","fund_standard_deviation_5years","fund_standard_deviation_10years","fund_r_squared_5years","fund_r_squared_10years"]

# %%
mutual_funds_2=mutual_funds_1.drop(columns=highestcorr)

# %%
mutual_funds_2.shape
# Out:
# (25308, 39)

# %%
corr_2=mutual_funds_2.corr()

# %%
mutual_funds=mutual_funds_2

# %%
mutual_funds_blend=mutual_funds[mutual_funds['investment']=='Blend']
mutual_funds_bl=mutual_funds_blend[mutual_funds['size']=='Large']
mutual_funds_bm=mutual_funds_blend[mutual_funds['size']=='Medium']
mutual_funds_bs=mutual_funds_blend[mutual_funds['size']=='Small']
# Out:
# /Users/sivateja/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/sivateja/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/sivateja/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %%
print(mutual_funds_bl.shape)
print(mutual_funds_bm.shape)
print(mutual_funds_bs.shape)
# Out:
# (6933, 39)
# (2480, 39)
# (1007, 39)

# %%
mutual_funds_growth=mutual_funds[mutual_funds['investment']=='Growth']
mutual_funds_gl=mutual_funds_growth[mutual_funds['size']=='Large']
mutual_funds_gm=mutual_funds_growth[mutual_funds['size']=='Medium']
mutual_funds_gs=mutual_funds_growth[mutual_funds['size']=='Small']
# Out:
# /Users/sivateja/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/sivateja/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/sivateja/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %%
print(mutual_funds_gl.shape)
print(mutual_funds_gm.shape)
print(mutual_funds_gs.shape)
# Out:
# (4192, 39)
# (1718, 39)
# (850, 39)

# %%
mutual_funds_value=mutual_funds[mutual_funds['investment']=='Value']
mutual_funds_vl=mutual_funds_value[mutual_funds['size']=='Large']
mutual_funds_vm=mutual_funds_value[mutual_funds['size']=='Medium']
mutual_funds_vs=mutual_funds_value[mutual_funds['size']=='Small']
# Out:
# /Users/sivateja/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/sivateja/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/sivateja/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %%
print(mutual_funds_vl.shape)
print(mutual_funds_vm.shape)
print(mutual_funds_vs.shape)
# Out:
# (3221, 39)
# (1893, 39)
# (1512, 39)

# %%
mutual_funds_bl.to_csv(r'Mutualfunds/mf_blend_large.csv',index=False)
mutual_funds_bm.to_csv(r'Mutualfunds/mf_blend_medium.csv',index=False)
mutual_funds_bs.to_csv(r'Mutualfunds/mf_blend_small.csv',index=False)
mutual_funds_gl.to_csv(r'Mutualfunds/mf_growth_large.csv',index=False)
mutual_funds_gm.to_csv(r'Mutualfunds/mf_growth_medium.csv',index=False)
mutual_funds_gs.to_csv(r'Mutualfunds/mf_growth_small.csv',index=False)
mutual_funds_vl.to_csv(r'Mutualfunds/mf_value_large.csv',index=False)
mutual_funds_vm.to_csv(r'Mutualfunds/mf_value_medium.csv',index=False)
mutual_funds_vs.to_csv(r'Mutualfunds/mf_value_small.csv',index=False)

# %%
mutual_funds_bl=pd.read_csv(r'Mutualfunds/mf_blend_large.csv')
mutual_funds_bm=pd.read_csv(r'Mutualfunds/mf_blend_medium.csv')
mutual_funds_bs=pd.read_csv(r'Mutualfunds/mf_blend_small.csv')
mutual_funds_gl=pd.read_csv(r'Mutualfunds/mf_growth_large.csv')
mutual_funds_gm=pd.read_csv(r'Mutualfunds/mf_growth_medium.csv')
mutual_funds_gs=pd.read_csv(r'Mutualfunds/mf_growth_small.csv')
mutual_funds_vl=pd.read_csv(r'Mutualfunds/mf_value_large.csv')
mutual_funds_vm=pd.read_csv(r'Mutualfunds/mf_value_medium.csv')
mutual_funds_vs=pd.read_csv(r'Mutualfunds/mf_value_small.csv')

# %%
remove_investment_size=['investment','size']

# %%
mutual_funds_bl=mutual_funds_bl.drop(columns=remove_investment_size)
mutual_funds_bm=mutual_funds_bm.drop(columns=remove_investment_size)
mutual_funds_bs=mutual_funds_bs.drop(columns=remove_investment_size)
mutual_funds_gl=mutual_funds_gl.drop(columns=remove_investment_size)
mutual_funds_gm=mutual_funds_gm.drop(columns=remove_investment_size)
mutual_funds_gs=mutual_funds_gs.drop(columns=remove_investment_size)
mutual_funds_vl=mutual_funds_vl.drop(columns=remove_investment_size)
mutual_funds_vm=mutual_funds_vm.drop(columns=remove_investment_size)
mutual_funds_vs=mutual_funds_vs.drop(columns=remove_investment_size)

# %%
print(mutual_funds_bl.shape)
print(mutual_funds_bm.shape)
print(mutual_funds_bs.shape)
print(mutual_funds_gl.shape)
print(mutual_funds_gm.shape)
print(mutual_funds_gs.shape)
print(mutual_funds_vl.shape)
print(mutual_funds_vm.shape)
print(mutual_funds_vs.shape)
# Out:
# (6933, 37)
# (2480, 37)
# (1007, 37)
# (4192, 37)
# (1718, 37)
# (850, 37)
# (3221, 37)
# (1893, 37)
# (1512, 37)

# %%
mutual_funds_bl.to_csv(r'Mutualfunds/mf_blend_large.csv',index=False)
mutual_funds_bm.to_csv(r'Mutualfunds/mf_blend_medium.csv',index=False)
mutual_funds_bs.to_csv(r'Mutualfunds/mf_blend_small.csv',index=False)
mutual_funds_gl.to_csv(r'Mutualfunds/mf_growth_large.csv',index=False)
mutual_funds_gm.to_csv(r'Mutualfunds/mf_growth_medium.csv',index=False)
mutual_funds_gs.to_csv(r'Mutualfunds/mf_growth_small.csv',index=False)
mutual_funds_vl.to_csv(r'Mutualfunds/mf_value_large.csv',index=False)
mutual_funds_vm.to_csv(r'Mutualfunds/mf_value_medium.csv',index=False)
mutual_funds_vs.to_csv(r'Mutualfunds/mf_value_small.csv',index=False)
